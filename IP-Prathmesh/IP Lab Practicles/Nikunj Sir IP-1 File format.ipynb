# %% [markdown]
# Python code to convert image in differnt format
# 1) JPEG - Joint Photographic Expert Group
# 2) PNG - Portable Network Graphics
# 3) TIFF - Tag Image File Format
# 4) GIF (Graphics Interchange Format

# %% [raw]
# Common File Format

# %% [raw]
# JPEG (Joint Photographic Experts Group)
#
# File Extensions: .jpg, .jpeg
# Compression: Lossy
# Best for: Photographs and images with many colors and gradients.
# Features:
# Reduces file size by removing non-essential data (lossy compression).
# Commonly used for web images due to smaller file sizes.
# Doesn't support transparency.
# Quality decreases with repeated saving and compression.
# Usage: Ideal for web images, social media, and email attachments.

# %% [raw]
# PNG (Portable Network Graphics)
#
# File Extension: .png
# Compression: Lossless
# Best for: Images with transparency and graphics that need to preserve quality.
# Features:
# Supports lossless compression, meaning no loss in image quality.
# Supports transparency (alpha channel), making it useful for logos and web images with transparent backgrounds.
# Larger file size compared to JPEG.
# Usage: Often used for web graphics, logos, and images that require transparency.

# %% [raw]
# GIF (Graphics Interchange Format)
#
# File Extension: .gif
# Compression: Lossless
# Best for: Simple graphics, logos, and animated images.
# Features:
# Limited to 256 colors (8-bit color palette), making it unsuitable for detailed images or photographs.
# Supports transparency, but only in a binary form (either fully transparent or opaque).
# Supports animation, making it popular for short looping images or memes.
# Usage: Used for animations, small icons, and low-resolution images.

# %% [raw]
# TIFF (Tagged Image File Format)
#
# File Extension: .tiff, .tif
# Compression: Lossless (optional lossy compression)
# Best for: High-quality images and professional editing.
# Features:
# Known for storing images without any loss of quality (lossless compression).
# Can store multiple layers and image data like alpha channels.
# Supports large image sizes.
# Produces large file sizes, making it unsuitable for web usage.
# Usage: Preferred in professional environments like photography, publishing, and printing.

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [raw]
# Python Code for File Format Coversion

# %%
import imageio.v3 as iio
import matplotlib.pyplot as plt
from PIL import Image

# Load an image using imageio
def load_image(file_path):
    """
    Load an image from the specified file path using imageio.
    
    Parameters:
    - file_path (str): The path to the image file to be loaded.
    
    Returns:
    - image (numpy.ndarray): The loaded image array.
    """
    image = iio.imread(file_path)
    return image

def display_image(image):
    """
    Display an image using matplotlib.
    
    Parameters:
    - image (numpy.ndarray): The image array to be displayed.
    """
    plt.imshow(image)
    plt.axis('off')  # Hide the axes
    plt.show()

# Save image using Pillow (convert numpy array to PIL Image)
def save_image(image, output_path, format):
    """
    Save an image in a specified format to the given output path.
    
    Parameters:
    - image (numpy.ndarray): The image array to be saved.
    - output_path (str): The path where the image will be saved.
    - format (str): The format to save the image in (e.g., 'JPEG', 'PNG', 'TIFF').
    """
    pil_image = Image.fromarray(image)
    pil_image.save(output_path, format=format)

# Main function to demonstrate the process
def main():
    # File paths
    input_file_path = r"C:\Users\roari\Downloads\Mountain.jpg"  # Path to the input image
    output_file_path_jpeg = r"C:\Users\roari\Downloads\Mountain_converted.jpg"  # Path to save the JPEG version
    output_file_path_png = r"C:\Users\roari\Downloads\Mountain_converted.png"   # Path to save the PNG version
    output_file_path_tiff = r"C:\Users\roari\Downloads\Mountain_converted.tiff" # Path to save the TIFF version

    # Load the image
    image = load_image(input_file_path)

    # Display the image
    display_image(image)

    # Save the image in different formats
    save_image(image, output_file_path_jpeg, 'JPEG')
    save_image(image, output_file_path_png, 'PNG')
    save_image(image, output_file_path_tiff, 'TIFF')

# Call the main function directly
main()

# %% [markdown]
# Find these images in download of the pc

# %%
from PIL import Image
import matplotlib.pyplot as plt

def display_image(file_path, title):
    """
    Display an image from the specified file path.
    
    Parameters:
    - file_path (str): The path to the image file to be displayed.
    - title (str): The title of the plot.
    """
    image = Image.open(file_path)
    plt.imshow(image)
    plt.title(title)
    plt.axis('off')
    plt.show()

# Display the converted images
display_image(r"C:\Users\roari\Downloads\Mountain_converted.jpg", 'JPEG Format')
display_image(r"C:\Users\roari\Downloads\Mountain_converted.png", 'PNG Format')
display_image(r"C:\Users\roari\Downloads\Mountain_converted.tiff", 'TIFF Format')

# %% [raw]
# GIF Conversion

# %%
pip install Pillow
# Out:
# Requirement already satisfied: Pillow in c:\users\roari\anaconda3\lib\site-packages (10.4.0)Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image

# Load the JPG image
jpg_image_path = r"C:\Users\roari\Downloads\Bird 6.jpg"
gif_image_path = r"C:\Users\roari\Downloads\Bird 6.gif"

# Open the JPG image
with Image.open(jpg_image_path) as img:
    # Convert to GIF and save it
    img.convert('RGB').save(gif_image_path, 'GIF')

# Open and display the GIF image
with Image.open(gif_image_path) as gif_img:
    gif_img.show()

# %%
from IPython.display import Image, display

# Paths to the images
jpg_image_path = r"C:\Users\roari\Downloads\Bird 6.jpg"
gif_image_path = r"C:\Users\roari\Downloads\Bird 6.gif"

# Display the original JPG image
print("Original JPG Image:")
display(Image(filename=jpg_image_path))

# Display the converted GIF image
print("Converted GIF Image:")
display(Image(filename=gif_image_path))
# Out:
# Original JPG Image:
# Converted GIF Image:

# %% [markdown]
# END
